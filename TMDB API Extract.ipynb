# %% [markdown]
# # Extracting From TMDB
# - Victoria White
# - 19 October 2022

# %%
# !pip install tmdbsimple

# %%
import json 
import tmdbsimple as tmdb
import pandas as pd
import os, time, json

# %%
#defining function to find certification
def get_movie_with_rating(movie_id):
    movie = tmdb.Movies(movie_id)
    movie_info = movie.info()
    releases = movie.releases()
    for c in releases['countries']:
        if c['iso_3166_1'] == 'US':
            info['certification'] = c['certification']
    return movie_info

# %%
def write_json(new_data, filename): 

    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %% [markdown]
# ## Exploring Movies

# %%
#load login credentials
with open('/Users/mrsvw/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
#accessing database
tmdb.API_KEY = login['api-key']

# %%
#exploring movies
movie = tmdb.Movies(582)

# %%
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/3mxteiwtcCPjbYKlyC0WxY1G9J3.jpg',
#  'belongs_to_collection': None,
#  'budget': 2000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}],
#  'homepage': '',
#  'id': 582,
#  'imdb_id': 'tt0405094',
#  'original_language': 'de',
#  'original_title': 'Das Leben der Anderen',
#  'overview': 'A tragic love story set in East Berlin with the backdrop of an undercover Stasi controlled culture. Stasi captain Wieler is ordered to follow author Dreyman and plunges deeper and deeper into his life until he reaches the threshold of doubting the system.',
#  'popularity': 13.679,
#  'poster_path': '/bCywq0RkrdI2qzhPNuuJ9PvGuzd.jpg',
#  'production_companies': [{'id': 58,
#    'logo_path': '/voYCwlBHJQANtjvm5MNIkCF1dDH.png',
#    'name': 'Sony Pictures Classics',
#    'origin_country': 'US'},
#   {'id': 336,
#    'logo_path': '/4YJDtfNDyI1ustIo6KttzEuIvQz.png',
#    'name': 'Wiedemann & Berg Film',
#    'origin_country': 'DE'},
# ...

# %%
info['budget']
# Out:
# 2000000

# %%
info['revenue']
# Out:
# 70000000

# %%
info['imdb_id']
# Out:
# 'tt0405094'

# %%
movie = tmdb.Movies('tt1361336')
info = movie.info()
info['budget']
# Out:
# 50000000

# %%
#testing function
test = get_movie_with_rating("tt0848228")
test
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 196.814,
#  'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
# ...

# %%
test_ids = ["tt0848228", "tt0115937","tt0848228","tt0332280"]
results = []
errors = []
for movie_id in test_ids:
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
    except Exception as e:
        errors.append([movie_id, e])
test_df = pd.DataFrame(results)
test_df
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 2  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 2                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 2  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
# ...

# %%
print(f'-Number of errors: {len(errors)}')
errors
# Out:
# -Number of errors: 1
# [['tt0115937',
#   requests.exceptions.HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0115937?api_key=7e92f997a3f2eb7c84fb67c0ca347c00')]]

# %% [markdown]
# ## Preparing to Extract

# %%
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['.ipynb_checkpoints',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json']

# %%
basics = pd.read_csv('Data/title_basics.csv.gz')
basics
# Out:
#            tconst  titleType  \
# 0       tt0035423      movie
# 1       tt0062336      movie
# 2       tt0069049      movie
# 3       tt0088751      movie
# 4       tt0096056      movie
# ...           ...        ...
# 282599  tt9916200  tvEpisode
# 282600  tt9916204  tvEpisode
# 282601  tt9916254      video
# 282602  tt9916348      video
# 282603  tt9916362      movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# 3                                       The Naked Monster
# 4                                    Crime and Punishment
# ...                                                   ...
# 282599                               The Great Experiment
# 282600                                      Better Angels
# 282601                               Big Tit Cream Pie 32
# ...

# %%
#defining list of years to extract from API
YEARS_TO_GET = [2000, 2001]
#defining error list
errors = []

# %%
from tqdm.notebook import tqdm_notebook

# %%
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    file_exists = os.path.isfile(JSON_FILE)
    
    if file_exists == False:
# save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)
        
    df = basics.loc[basics['startYear']==YEAR].copy()
# saving movie ids to list
    movie_ids = df['tconst'].copy()
    previous_df = pd.read_json(JSON_FILE)
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]
    
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        except Exception as e:
            continue
            errors.append([movie_id, e])
    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz",
                             compression="gzip", index=False)
# Out:
# ...
# Movies from 2001:   0%|          | 0/4222 [00:00<?, ?it/s]

# %%
final_year_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                  None
# 2  tt0114447    0.0                              None                  None
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                  None
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                  None
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
#
#          id original_language         original_title  ... release_date  \
# ...

# %%
#loading data for movies started in 2000
first_year_df = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
first_year_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %%
#loading data for movies started in 2001
second_year_df = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
second_year_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
# ...

# %%
final_year_df = pd.concat([first_year_df, second_year_df])
final_year_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %%
final_year_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3974 entries, 0 to 2018
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3974 non-null   object
#  1   adult                  3972 non-null   float64
#  2   backdrop_path          1775 non-null   object
#  3   belongs_to_collection  310 non-null    object
#  4   budget                 3972 non-null   float64
#  5   genres                 3972 non-null   object
#  6   homepage               258 non-null    object
#  7   id                     3972 non-null   float64
#  8   original_language      3972 non-null   object
#  9   original_title         3972 non-null   object
#  10  overview               3885 non-null   object
#  11  popularity             3972 non-null   float64
#  12  poster_path            3514 non-null   object
#  13  production_companies   3972 non-null   object
# ...
