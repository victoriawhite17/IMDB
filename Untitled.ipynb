# %% [markdown]
# # IMDB: Recommendations for a Successful Movie
# - Victoria White
# - 11 October 2022

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
#importing data
title_basics = 'https://datasets.imdbws.com/title.basics.tsv.gz'
title_akas = 'https://datasets.imdbws.com/title.akas.tsv.gz'
title_ratings = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %% [markdown]
# ## Saving Compressed Files

# %%
#creating folder for Data
import os
os.makedirs('Data/', exist_ok=True)
os.listdir("Data/")
# Out:
# ['title_akas.csv.gz', 'title_basics.csv.gz', 'title_ratings.csv.gz']

# %%
#saving dataframes as compressed files
df_basics.to_csv("Data/title_basics.csv.gz", compression='gzip', index=False)
df_akas.to_csv("Data/title_akas.csv.gz", compression='gzip', index=False)
df_ratings.to_csv("Data/title_ratings.csv.gz", compression='gzip',index=False)

# %%
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory=False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory=False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1917
# 1  tt0000002            5.8       260
# 2  tt0000005            6.2      2541
# 3  tt0000006            5.1       175
# 4  tt0000007            5.4       796

# %%
#basics = pd.read_csv(title_basics, sep='\t', low_memory=False)
df_basics = basics.copy()
df_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
#akas = pd.read_csv(title_akas, sep='\t', low_memory=False)
df_akas = akas.copy()
df_akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
#ratings = pd.read_csv(title_ratings, sep='\t', low_memory=False)
df_ratings = ratings.copy()
df_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1917
# 1  tt0000002            5.8       260
# 2  tt0000005            6.2      2541
# 3  tt0000006            5.1       175
# 4  tt0000007            5.4       796

# %% [markdown]
# ## Preprocessing

# %%
#replacing null values
df_basics.replace({'\\N':np.nan}, inplace=True)

# %%
#replacing null values
df_ratings.replace({'\\N':np.nan}, inplace=True)

# %%
#replacing null values
df_akas.replace({'\\N':np.nan}, inplace=True)

# %%
#checking for duplicates
df_basics.duplicated().sum()
# Out:
# 0

# %%
#checking for duplicates
df_akas.duplicated().sum()
# Out:
# 0

# %%
#checking for duplicates
df_ratings.duplicated().sum()
# Out:
# 0

# %%
#finding all missing values
df_basics.isna().sum()
# Out:
# tconst                 0
# titleType              0
# primaryTitle           0
# originalTitle          0
# isAdult                0
# startYear              0
# endYear           272504
# runtimeMinutes         0
# genres                 0
# dtype: int64

# %%
#eliminating movies that are null in runtimeMinutes and genres
df_basics.dropna(subset='runtimeMinutes', inplace=True)
df_basics.dropna(subset='genres', inplace=True)
df_basics.isna().sum()
# Out:
# tconst                 0
# titleType              0
# primaryTitle           0
# originalTitle          0
# isAdult                0
# startYear              0
# endYear           272504
# runtimeMinutes         0
# genres                 0
# dtype: int64

# %%
#changing dtype from object for startYear
df_basics.astype({'startYear':'int'}).dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult             int64
# startYear           int32
# endYear           float64
# runtimeMinutes      int64
# genres             object
# dtype: object

# %%
#filtering basics for movies after the year 2000
drop_movies = df_basics[(df_basics['titleType'] != 'Movie') &
                  (df_basics['startYear'] <=1999)].index
df_basics.drop(drop_movies, inplace=True)
df_basics.head(15)
# Out:
#        tconst titleType                                       primaryTitle  \
# 0   tt0035423     movie                                     Kate & Leopold
# 1   tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2   tt0069049     movie                         The Other Side of the Wind
# 3   tt0088751     movie                                  The Naked Monster
# 4   tt0096056     movie                               Crime and Punishment
# 5   tt0100275     movie                           The Wandering Soap Opera
# 6   tt0104278     movie                                       Flaming Ears
# 7   tt0108549     movie                         West from North Goes South
# 8   tt0111056  tvSeries                                 Gensomaden Saiyuki
# 9   tt0111159     movie                                       Shatter Dead
# 10  tt0113026     movie                                    The Fantasticks
# 11  tt0113092     movie                                      For the Cause
# 12  tt0114447     movie                                   The Silent Force
# 13  tt0115937     movie                                        Consequence
# 14  tt0116391     movie                                               Gang
#
#                                 originalTitle  isAdult  startYear  endYear  \
# 0                              Kate & Leopold        0       2001      NaN
# 1   El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                  The Other Side of the Wind        0       2018      NaN
# 3                           The Naked Monster        0       2005      NaN
# 4                        Crime and Punishment        0       2002      NaN
# 5                       La Telenovela Errante        0       2017      NaN
# 6                                Flaming Ears        0       2013      NaN
# 7                  West from North Goes South        0       2004      NaN
# 8                          Gensomaden Saiyuki        0       2000   2001.0
# 9                                Shatter Dead        0       2022      NaN
# 10                            The Fantasticks        0       2000      NaN
# 11                              For the Cause        0       2000      NaN
# 12                           The Silent Force        0       2001      NaN
# 13                                Consequence        0       2000      NaN
# 14                                       Gang        0       2000      NaN
#
#     runtimeMinutes                      genres
# 0              118      Comedy,Fantasy,Romance
# 1               70                       Drama
# 2              122                       Drama
# 3              100        Comedy,Horror,Sci-Fi
# 4              126                       Drama
# 5               80        Comedy,Drama,Fantasy
# 6               84              Fantasy,Sci-Fi
# 7               96              Comedy,Mystery
# 8               23  Action,Adventure,Animation
# 9               84                      Horror
# 10              86             Musical,Romance
# 11             100      Action,Adventure,Drama
# 12              90                      Action
# 13              91                       Drama
# 14             167          Action,Crime,Drama

# %%
#dropping short from titleType so only movie is included
short = df_basics[(df_basics['titleType'] == 'short')].index
df_basics.drop(short, inplace=True)
df_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
#dropping documentaries
is_documentary = df_basics['genres'].str.contains('documentary', case=False)
df_basics = df_basics[~is_documentary]
df_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
#filtering movies not in US region
not_US = df_akas[(df_akas['region'] != 'US')].index
df_akas.drop(not_US, inplace=True)
df_akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
#filtering akas dataframe on the basics dataframe
keepers_basics = df_basics['tconst'].isin(df_akas['titleId'])
keepers_basics
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 282599    True
# 282600    True
# 282601    True
# 282602    True
# 282603    True
# Name: tconst, Length: 282604, dtype: bool

# %%
#filtering basics
df_basics = df_basics[keepers_basics]
df_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
#filtering akas dataframe on ratings dataframe
keepers_ratings = df_ratings['tconst'].isin(df_akas['titleId'])
keepers_ratings
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 471730    True
# 471731    True
# 471732    True
# 471733    True
# 471734    True
# Name: tconst, Length: 471735, dtype: bool

# %%
#filtering ratings
df_ratings = df_ratings[keepers_ratings]
df_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1917
# 1  tt0000002            5.8       260
# 2  tt0000005            6.2      2541
# 3  tt0000006            5.1       175
# 4  tt0000007            5.4       796
